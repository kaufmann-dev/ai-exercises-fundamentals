# %%
# %pip install tensorflow
# %pip install pandas
# %pip install keras
# %pip install pandas
# %pip install sklearn
# %pip install numpy
# %pip install matplotlib
# %pip install xlrd
# %pip install PIL
